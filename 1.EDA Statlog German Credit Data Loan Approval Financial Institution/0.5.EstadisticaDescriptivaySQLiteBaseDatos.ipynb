# %% [markdown]
# ## Práctica: Medidas descriptivas y base de datos

# %%
import pandas as pd
#url = 'http://manage.humdata.org/hdx/api/exporter/indicator/csv/TT014/source/mdgs/fromYear/1950/toYear/0/language/en/TT014_Baseline.csv'

# %%
#from_url = pd.read_table(url,sep=",")
from_url = pd.read_csv('TT014_Baseline.csv',sep=';')
#help(pd.read_csv)

# %%
from_url
# Out:
#    Country code              Country name  2015  2014  2013  2012  2011  2010  \
# 0           AFG               AFGHANISTAN  27.7  27.7  27.7  27.7  27.7  27.3
# 1           AGO                    ANGOLA  36.8  36.8  34.1  38.2  38.6  38.6
# 2           ALB                   ALBANIA  20.7  20.0  15.7  15.7  16.4  16.4
# 3           AND                   ANDORRA  50.0  50.0  50.0  50.0  35.7  35.7
# 4           ARE      UNITED ARAB EMIRATES  17.5  17.5  17.5  17.5  22.5  22.5
# 5           ARG                 ARGENTINA  36.2  36.6  37.4  37.4  38.5  38.5
# 6           ARM                   ARMENIA  10.7  10.7  10.7   8.4   9.2   9.2
# 7           ATG       ANTIGUA AND BARBUDA  11.1  10.5  10.5  10.5  10.5  10.5
# 8           AUS                 AUSTRALIA  26.7  26.0  24.7  24.7  24.7  27.3
# 9           AUT                   AUSTRIA  30.6  32.2  27.9  27.9  27.9  27.9
# 10          AZE                AZERBAIJAN  15.6  15.6  16.0  16.0  16.0  11.4
# ...

# %%
from_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country code  34 non-null     object
#  1   Country name  34 non-null     object
#  2   2015          33 non-null     float64
#  3   2014          33 non-null     float64
#  4   2013          34 non-null     float64
#  5   2012          34 non-null     float64
#  6   2011          33 non-null     float64
#  7   2010          34 non-null     float64
#  8   2009          34 non-null     float64
#  9   2008          33 non-null     float64
#  10  2007          33 non-null     float64
#  11  2006          34 non-null     float64
#  12  2005          32 non-null     float64
#  13  2004          32 non-null     float64
#  14  2003          33 non-null     float64
#  15  2002          31 non-null     float64
#  16  2001          28 non-null     float64
# ...

# %%
#some_cols=pd.read_table(url,sep=',',usecols=[1,2,3,4,5,6,7])

# %%
some_cols=from_url
some_cols.head()
# Out:
#   Country code          Country name  2015  2014  2013  2012  2011  2010  \
# 0          AFG           AFGHANISTAN  27.7  27.7  27.7  27.7  27.7  27.3
# 1          AGO                ANGOLA  36.8  36.8  34.1  38.2  38.6  38.6
# 2          ALB               ALBANIA  20.7  20.0  15.7  15.7  16.4  16.4
# 3          AND               ANDORRA  50.0  50.0  50.0  50.0  35.7  35.7
# 4          ARE  UNITED ARAB EMIRATES  17.5  17.5  17.5  17.5  22.5  22.5
#
#    2009  2008  ...  1999  1998  1997  1996  1995  1994  1993  1992  1991  1990
# 0  27.7  27.7  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   3.7
# 1  37.3  15.0  ...  15.5   9.5   9.5   NaN   NaN   NaN   NaN   NaN   NaN  14.5
# 2   7.1   7.1  ...   NaN   NaN  12.1   NaN   NaN   NaN   NaN   NaN   NaN  28.8
# 3  25.0  25.0  ...   7.1   7.1   3.6   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  22.5  22.5  ...   0.0   0.0   0.0   NaN   NaN   NaN   NaN   NaN   NaN   0.0
#
# [5 rows x 28 columns]

# %%
some_cols.describe()
# Out:
#             2015       2014       2013       2012       2011       2010  \
# count  33.000000  33.000000  34.000000  34.000000  33.000000  34.000000
# mean   21.824242  20.984848  19.650000  19.667647  19.321212  18.888235
# std    12.281389  11.291261  10.579662  11.113893  10.708897  10.633075
# min     3.100000   3.100000   3.100000   0.000000   0.000000   0.000000
# 25%    11.100000  10.500000  10.550000  10.625000  10.500000  10.125000
# 50%    20.400000  20.000000  16.750000  16.750000  16.700000  17.500000
# 75%    30.500000  27.700000  26.300000  27.125000  27.700000  27.300000
# max    53.100000  50.000000  50.000000  50.000000  39.300000  38.600000
#
#             2009       2008       2007       2006  ...       1999       1998  \
# count  34.000000  33.000000  33.000000  34.000000  ...  27.000000  26.000000
# mean   17.585294  17.239394  16.972727  16.538235  ...  11.585185  10.411538
# std    10.393213   9.886036   9.547980   9.839624  ...   7.303092   6.974659
# ...

# %%
#sqlite3 base.db
#.databases
#.tables
#.schema recoleccion

CREATE TABLE Paises (
    countryId int,
    countryCode varchar(4),
    countryName varchar(255),
    mediaActual DOUBLE,
    varianzaActual DOUBLE,
    maxActual DOUBLE,
    minActual DOUBLE
);

INSERT INTO Paises (countryId,countryCode, countryName)
VALUES (1,'AFG', 'AFGHANISTAN');

INSERT INTO Paises (countryId,countryCode, countryName)
VALUES (2,'AGO', 'ANGOLA');

INSERT INTO Paises (countryId,countryCode, countryName)
VALUES (3,'ALB', 'ALBANIA');

# %%
# !pip install pandas

# %%
import sqlite3
import pandas as pd
N=5 #para mostrar los N primeros
conn = sqlite3.connect('db/base.db')
c = conn.cursor()
consulta="SELECT * FROM Paises"
c.execute(consulta)
results = c.fetchall()
#print(type(results))
numRegistrosEncontrados=len(results) 
df = pd.DataFrame(results)

df.columns=['countryId','countryCode','countryName','mediaActual','varianzaActual','maxActual','minActual']
conn.close()
print(numRegistrosEncontrados)
df.head()
# Out:
# 3
#    countryId countryCode  countryName mediaActual varianzaActual maxActual  \
# 0          1         AFG  AFGHANISTAN        None           None      None
# 1          2         AGO       ANGOLA        None           None      None
# 2          3         ALB      ALBANIA        None           None      None
#
#   minActual
# 0      None
# 1      None
# 2      None

# %%
import sqlite3
import pandas as pd
N=5 #para mostrar los N primeros
conn = sqlite3.connect('db/bdventas3.sqlite')
c = conn.cursor()
print('*********** Tabla Productos')
consulta="SELECT * FROM Productos"
c.execute(consulta)
results = c.fetchall()
#print(type(results))
numRegistrosEncontrados=len(results) 
df = pd.DataFrame(results)

df.columns=['ID','Descripción','Costo']

print('cantidad de productos:',numRegistrosEncontrados)
print(df.head())

print('*********** Tabla Store')
consulta="SELECT * FROM Store"
c.execute(consulta)
results = c.fetchall()
#print(type(results))
numRegistrosEncontrados=len(results) 
df = pd.DataFrame(results)

df.columns=['ID','Descripción']
print('cantidad de sucursales:',numRegistrosEncontrados)
print(df.head())

print('*********** Tabla Time')
consulta="SELECT * FROM Time"
c.execute(consulta)
results = c.fetchall()
#print(type(results))
numRegistrosEncontrados=len(results) 
df = pd.DataFrame(results)

df.columns=['ID','Descripción']
print('cantidad de días:',numRegistrosEncontrados)
print(df.head())

conn.close()
# Out:
# *********** Tabla Productos
# cantidad de productos: 4
#    ID     Descripción   Costo
# 0   1      Televisión  150,75
# 1   2    Refrigerador  554,99
# 2   3      Microondas    76.0
# 3   4  Lavadora Super  1200.0
# *********** Tabla Store
# cantidad de sucursales: 5
#    ID                     Descripción
# 0   1             Supermaxi El Vergel
# 1   2  Supermaxi Av. De las Aaméricas
# 2   3             Supermaxi El Vecino
# 3   4                 Supermaxi Racar
# 4   5              Supermaxi Misicata
# *********** Tabla Time
# cantidad de días: 3
#    ID Descripción
# 0   1  10-11-2021
# 1   2  11-11-2021
# 2   3  12-11-2021

# %%
#INSERT
#INSERT INTO nombre_tabla
#VALUES (valor1, valor2, valor3, .)

#INSERT INTO nombre_tabla (columna1, columna2, columna3,.)
#VALUES (valor1, valor2, valor3, .)

import sqlite3
import pandas as pd
conn = sqlite3.connect('db/base.db')
c = conn.cursor()

#CRUD 
#C: create -> insert
#R: read -> select
#U: update -> update
#D: delete -> delete
    
consulta="INSERT INTO PAISES (countryId, countryCode, countryName, mediaActual, varianzaActual, maxActual, minActual) VALUES (5,'ARG','ARGENTINA',24,3,65,12)"
print(consulta)
c.execute(consulta)
conn.commit()
print(c.lastrowid)

conn.close()
# Out:
# INSERT INTO PAISES (countryId, countryCode, countryName, mediaActual, varianzaActual, maxActual, minActual) VALUES (5,'ARG','ARGENTINA',24,3,65,12)
# 5

# %%
#UPDATE
#UPDATE nombre_tabla
#SET columna1 = valor1, columna2 = valor2
#WHERE columna3 = valor3

import sqlite3
import pandas as pd
conn = sqlite3.connect('db/base.db')
c = conn.cursor()

consulta="UPDATE PAISES SET mediaActual=100, countryCode='ECU', countryName='Ecuador' WHERE countryId=4"
print(consulta)
c.execute(consulta)
conn.commit()
conn.close()
# Out:
# UPDATE PAISES SET mediaActual=100, countryCode='ECU', countryName='Ecuador' WHERE countryId=4

# %%
#DELETE
#DELETE FROM nombre_tabla
#WHERE nombre_columna = valor

import sqlite3
import pandas as pd

def eliminarPais(codigo):
    conn = sqlite3.connect('db/base.db')
    c = conn.cursor()
    consulta="DELETE FROM PAISES WHERE countryId="+str(codigo)
    print(consulta)
    c.execute(consulta)
    conn.commit()
    conn.close()
    
codigo=3
eliminarPais(codigo)
# Out:
# DELETE FROM PAISES WHERE countryId=3

# %%
#Consulta Multitabla
import sqlite3
import pandas as pd
N=5 #para mostrar los N primeros
conn = sqlite3.connect('db/bdventas3.sqlite')
c = conn.cursor()
print('*********** Tabla')
consulta="SELECT * FROM Productos p, Sales s where p.ProductID=s.ProductID and p.ProductID=1"
print(consulta)
c.execute(consulta)
results = c.fetchall()
#print(type(results))
numRegistrosEncontrados=len(results) 
df = pd.DataFrame(results)

df.columns=['ID','Descripción','Costo','DateID','ProductID','StoreID','Cantidad']

print('cantidad de productos:',numRegistrosEncontrados)


conn.close()

df.head()
# Out:
# *********** Tabla
# SELECT * FROM Productos p, Sales s where p.ProductID=s.ProductID and p.ProductID=1
# cantidad de productos: 2
#    ID Descripción   Costo  DateID  ProductID  StoreID  Cantidad
# 0   1  Televisión  150,75       1          1        1       3.0
# 1   1  Televisión  150,75       1          1        2     200.0

# %%
#el max y mínimo se toma de todo el conjunto de datos
some_cols.describe()
# Out:
#             2015       2014       2013       2012       2011       2010  \
# count  33.000000  33.000000  34.000000  34.000000  33.000000  34.000000
# mean   21.824242  20.984848  19.650000  19.667647  19.321212  18.888235
# std    12.281389  11.291261  10.579662  11.113893  10.708897  10.633075
# min     3.100000   3.100000   3.100000   0.000000   0.000000   0.000000
# 25%    11.100000  10.500000  10.550000  10.625000  10.500000  10.125000
# 50%    20.400000  20.000000  16.750000  16.750000  16.700000  17.500000
# 75%    30.500000  27.700000  26.300000  27.125000  27.700000  27.300000
# max    53.100000  50.000000  50.000000  50.000000  39.300000  38.600000
#
#             2009       2008       2007       2006  ...       1999       1998  \
# count  34.000000  33.000000  33.000000  34.000000  ...  27.000000  26.000000
# mean   17.585294  17.239394  16.972727  16.538235  ...  11.585185  10.411538
# std    10.393213   9.886036   9.547980   9.839624  ...   7.303092   6.974659
# ...

# %% [markdown]
# <count:> esta es la cantidad de valores incluidos en las estadísticas.
#
# <mean:> este es el promedio de los valores.
#
# <std:> esta es la desviación estándar de la distribución.
#
# <min:> este es el valor más bajo de la distribución.
#
# 25%: este es el valor del primer cuartil. El 25 % de los valores se encuentran en o por debajo de este valor.
#
# 50%: este es el valor para el segundo cuartil. El 50 % de los valores se encuentran en o por debajo de este valor. También es el valor de la mediana.
#
# 75%: este es el valor para el tercer cuartil. El 75 % de los valores se encuentran en o por debajo de este valor.
#
# <max:> este es el valor más alto de la distribución.

# %%
correl = some_cols.corr()
correl
# Out:
#           2015      2014      2013      2012      2011      2010      2009  \
# 2015  1.000000  0.891614  0.883266  0.880422  0.856531  0.838227  0.723160
# 2014  0.891614  1.000000  0.928732  0.923658  0.891743  0.891704  0.841078
# 2013  0.883266  0.928732  1.000000  0.992847  0.947392  0.945987  0.848344
# 2012  0.880422  0.923658  0.992847  1.000000  0.959024  0.957486  0.864711
# 2011  0.856531  0.891743  0.947392  0.959024  1.000000  0.993929  0.940086
# 2010  0.838227  0.891704  0.945987  0.957486  0.993929  1.000000  0.945355
# 2009  0.723160  0.841078  0.848344  0.864711  0.940086  0.945355  1.000000
# 2008  0.689964  0.787434  0.818199  0.806994  0.873919  0.879848  0.914800
# 2007  0.688667  0.778525  0.831083  0.818180  0.860702  0.866926  0.881217
# 2006  0.677002  0.749162  0.805193  0.792405  0.801117  0.807427  0.802351
# 2005  0.576313  0.666177  0.645833  0.639604  0.695298  0.700142  0.771263
# ...

# %%
#!pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(correl)
plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-11-495ae0b97e85>:4: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "tight_layout" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('attribute_correlations.png', tight_layout=True)

# %% [markdown]
# $a_i=45$

# %% [markdown]
# $f(x)=p^2*(1-p)$
