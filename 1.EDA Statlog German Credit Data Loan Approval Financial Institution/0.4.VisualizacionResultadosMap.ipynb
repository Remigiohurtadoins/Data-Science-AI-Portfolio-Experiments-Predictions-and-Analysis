# %%
#Extracción de Datos
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
dataset = pd.read_csv('Datasets/student_scores.csv')  
print(dataset.shape[1]) 
dataset.head()
# Out:
# 2
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
dataset.describe()

# %%
#Visualización para analisis manual
dataset.plot(x='Hours', y='Scores', style='x')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %%
dirResultados="Datasets/Resultados.csv"
df_gridsearch=pd.read_csv(dirResultados,sep=';')
df_gridsearch.head()
# Out:
#   METHOD   K      RMSE  N  PRECISION   RECALL
# 0    RAP  20  0.904981  5   0.631579  0.00671
# 1    RAP  20  0.904981  6   0.650000  0.00773
# 2    RAP  20  0.904981  7   0.666667  0.01050
# 3    RAP  20  0.904981  8   0.680000  0.01170
# 4    RAP  20  0.904981  9   0.692308  0.01290

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns
sns.set()

# %matplotlib inline

import cufflinks as cf

import chart_studio.plotly as py

# Import modules to work with data visualizations offline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# Connect to the plotly.js CDN with the init_notebook_mode() method
# so that the js code is fetched from a cdn, not saved into the notebook
init_notebook_mode(connected=True)

# Use cufflinks offline, don't push plots to the cloud
cf.go_offline()

import plotly.graph_objs as go

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

#from data_processing import *
#from ml import *

#df_gridsearch.RMSE.max()

#df_gridsearch.RMSE.sort_values().reset_index(drop=True)

#df = pd.DataFrame(data=df_gridsearch.RMSE.sort_values().reset_index(drop=True))
#df

#df['size'] = (df.RMSE / df.RMSE.max()) ** 100 * 20 + 1

# Linear scale

trace = go.Scatter3d(
    x=df_gridsearch['K'],
    y=df_gridsearch['RECALL'],
    z=df_gridsearch['PRECISION'],
    mode='markers', 
    marker=dict(
        #size=df_gridsearch.RMSE **  (1 / 3),
        size=(1- df_gridsearch.RMSE) * 150 + 1,
        #size=(1- (df_gridsearch.RMSE / df_gridsearch.RMSE.max())) * 500 + 1,
        #size=(df_gridsearch.RMSE / df_gridsearch.RMSE.max()) ** 100 * 20 + 1,
        #size=15,
        color=df_gridsearch.RMSE,
        opacity=0.99,
        colorscale='Viridis',
        colorbar=dict(title = 'Test score'),
        line=dict(color='rgb(140, 140, 170)')
    ),
    #text=df_gridsearch.Text,
    text=df_gridsearch.METHOD,
    hoverinfo='text'
)

data = [trace]
layout = go.Layout(
    title='3D visualization of the grid search results',
    margin=dict(
        l=30,
        r=30,
        b=30,
        t=30
    ),
#     height=600,
#     width=960,
    scene = dict(
        xaxis = dict(
            title='K',
            nticks=10
        ),
        yaxis = dict(
            title='RECALL',
        ),
        zaxis = dict(
            title='PRECISION',

        ),
    ),
 
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)

#<iframe
#  src="the/path/to/chart-name.html"
#  width="800"
#  height="600"
#  title="chart name"
#  style="border:none">
#</iframe>

fig.write_html("imagen3D.html")

#https://www.python-graph-gallery.com/plotly/
#https://qiita.com/bmj0114/items/8009f282c99b77780563   #grid search map 2D  
#https://towardsdatascience.com/using-3d-visualizations-to-tune-hyperparameters-of-ml-models-with-python-ba2885eab2e9
#https://github.com/xoelop/Medium-posts/blob/master/3d%20cross%20validation/ML%206%20-%20Gridsearch%20visulizations%20.ipynb

#%%html
#<iframe src="../../interactiveCharts/parallel-coordinate-plot-plotly.html" width="800" height="600" title="parallel coordinate chart with plotly" style="border:none"></iframe>
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df_gridsearch.RMSE.max()

df_gridsearch.RMSE.sort_values().reset_index(drop=True)

df = pd.DataFrame(data=df_gridsearch.RMSE.sort_values().reset_index(drop=True))
df

df['size'] = (df.RMSE / df.RMSE.max()) ** 100 * 20 + 1

df.iplot(kind='scatter', 
         mode='lines',
         x='RMSE',
         size=5,
         xTitle='Mean test score',
         yTitle='Size',
         title='Size of the points as a function of the mean test score')

df_gridsearch['size'] = (df_gridsearch.RMSE / 
                         df_gridsearch.RMSE.max()) ** 100 * 20 + 1
# Out:
# <div>                            <div id="3fcf09aa-868d-4fcf-98fa-882aaea69903" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# library

# https://www.python-graph-gallery.com/
