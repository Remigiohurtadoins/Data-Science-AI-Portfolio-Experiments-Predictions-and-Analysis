# %% [markdown]
# <h3> Ejercicio de árboles de decisión para maximizar Information Gain (IG) utilizando medidas de impureza</h3>
# <div style="color:#3c4d5a; border-top: 6px solid orange; padding: 5px; text-align: center; text-transform: uppercase"></div>

# %% [markdown]
# - Gini impurity (IG)
# - Classification error (IE)
# - Entropía (IH)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# <h5>Los resultados que se generaron en exel</h5>
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Según estos resultados, el primer árbol tiene mejores medidas de impureza
